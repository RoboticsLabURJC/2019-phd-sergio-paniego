# %%
import sys
import json
import yaml
import rosbag


bags = []
#bag_1 = '20201228-145515.bag'
#bag_2 = '20201228-145852.bag'
#bag_3 = '20201228-150228.bag'
#bag_4 = '20201228-150604.bag'
#bag_5 = '20201228-150637.bag'
#bag_6 = '20201228-150700.bag'
#bag_7 = '20201228-150723.bag'
#bag_8 = '20201228-151103.bag'


bag_1 = 'first_experiment_bags/20201229-100323.bag'
bag_2 = 'first_experiment_bags/20201229-100642.bag'
bag_3 = 'first_experiment_bags/20201229-100909.bag'
bag_4 = 'first_experiment_bags/20201229-101149.bag'
bag_5 = 'first_experiment_bags/20201229-101241.bag'
bag_6 = 'first_experiment_bags/20201229-101446.bag'
bag_7 = 'first_experiment_bags/20201229-101517.bag'
bag_8 = 'first_experiment_bags/20201229-101831.bag'
bag_9 = 'first_experiment_bags/20201229-102147.bag'
bag_10 = 'first_experiment_bags/20201229-102227.bag'
bag_11 = 'first_experiment_bags/20201229-102353.bag'
bag_12 = 'first_experiment_bags/20201229-102607.bag'
bag_13 = 'first_experiment_bags/20201229-102628.bag'
bag_14 = 'first_experiment_bags/20201229-102701.bag'
bag_15 = 'first_experiment_bags/20201229-103226.bag'
bag_16 = 'first_experiment_bags/20201229-103747.bag'
bag_17 = 'first_experiment_bags/20201229-104309.bag'
bag_18 = 'first_experiment_bags/20201229-104830.bag'
bag_19 = 'first_experiment_bags/20201229-104904.bag'
bag_20 = 'first_experiment_bags/20201229-104927.bag'
bag_21 = 'first_experiment_bags/20201229-105005.bag'
bag_22 = 'first_experiment_bags/20201229-105033.bag'
bag_23 = 'first_experiment_bags/20201229-105110.bag'
bag_24 = 'first_experiment_bags/20201229-105633.bag'
bag_25 = 'first_experiment_bags/20201229-121245.bag'
bag_26 = 'first_experiment_bags/20201229-121601.bag'
bag_27 = 'first_experiment_bags/20201229-121919.bag'
bag_28 = 'first_experiment_bags/20201229-121955.bag'
bag_29 = 'first_experiment_bags/20201229-122036.bag'
bag_30 = 'first_experiment_bags/20201229-122559.bag'
bag_31 = 'first_experiment_bags/20201229-122629.bag'
bag_32 = 'first_experiment_bags/20201229-122708.bag'
bag_33 = 'first_experiment_bags/20201229-134355.bag'
bag_34 = 'first_experiment_bags/20201229-134429.bag'
bag_35 = 'first_experiment_bags/20201229-134503.bag'
bag_36 = 'first_experiment_bags/20201229-134528.bag'



bags.append(bag_1)
bags.append(bag_2)
bags.append(bag_3)
bags.append(bag_4)
bags.append(bag_5)
bags.append(bag_6)
bags.append(bag_7)
bags.append(bag_8)
bags.append(bag_9)
bags.append(bag_10)
bags.append(bag_11)
bags.append(bag_12)
bags.append(bag_13)
bags.append(bag_14)
bags.append(bag_15)
bags.append(bag_16)
bags.append(bag_17)
bags.append(bag_18)
bags.append(bag_19)
bags.append(bag_20)
bags.append(bag_21)
bags.append(bag_22)
bags.append(bag_23)
bags.append(bag_24)
bags.append(bag_25)
bags.append(bag_26)
bags.append(bag_27)
bags.append(bag_28)
bags.append(bag_29)
bags.append(bag_30)
bags.append(bag_31)
bags.append(bag_32)
bags.append(bag_33)
bags.append(bag_34)
bags.append(bag_35)
bags.append(bag_36)



bags_checkpoints = []
bags_metadata = []

for bag_file in bags:
    print('------------------BAG----------------')
    bag = rosbag.Bag(bag_file)
    print(bag_file)
    bag_checkpoints = []
    for topic, point, t in bag.read_messages(topics=['/F1ROS/odom']):
        bag_checkpoints.append(point)
    bags_checkpoints.append(bag_checkpoints)
    
    for topic, point, t in bag.read_messages(topics=['/metadata']):
    
        y = yaml.load(str(point), Loader=yaml.FullLoader)
        h = json.dumps(y,indent=4)
        data = json.loads(h)
        metadata = json.loads(data['data'])
        #print(metadata)
        print(metadata['world'])
        print(metadata['brain_path'])
        print(metadata['robot_type'])
        bags_metadata.append(metadata)
        print(len(bag_checkpoints))
        
        
    bag.close()
    print('----------------------------------')

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import metrics

experiments_statistics = []
world_completed = {}

for x, checkpoints in enumerate(bags_checkpoints):
    x_points = []
    y_points = []
    print('-------------------------------------------')
    print('WORLD -> ' + bags_metadata[x]['world'])
    print('BRAIN PATH -> ' + bags_metadata[x]['brain_path'])
    print('ROBOT TYPE -> ' + bags_metadata[x]['robot_type'])
    experiment_statistics = {}
    experiment_statistics['world'] = bags_metadata[x]['world']
    experiment_statistics['brain_path'] = bags_metadata[x]['brain_path']
    experiment_statistics['robot_type'] = bags_metadata[x]['robot_type']
    if bags_metadata[x]['world'] == 'simple_circuit.launch':
        perfect_lap_path = 'lap-simple-circuit.bag'
    elif bags_metadata[x]['world'] == 'many_curves.launch':
        perfect_lap_path = 'lap-many-curves.bag'
        
    perfect_lap_checkpoints, circuit_diameter = metrics.read_perfect_lap_rosbag(perfect_lap_path)
    print('CIRCUIT DIAMETER -> ' + str(circuit_diameter))
    lap_statistics = metrics.lap_percentage_completed(bags[x], perfect_lap_checkpoints, circuit_diameter)
    experiment_statistics['lap_statistics'] = lap_statistics
    experiments_statistics.append(experiment_statistics)
    print('COMPLETED DISTANCE -> ' + str(lap_statistics['completed_distance']))
    print('PERCENTAGE COMPLETED -> ' + str(lap_statistics['percentage_completed']))
    if lap_statistics['percentage_completed'] > 100:
        if bags_metadata[x]['world'] in world_completed and bags_metadata[x]['brain_path'] in world_completed[bags_metadata[x]['world']]:
            print('--- ENTRA 1 ---')
            world_completed[bags_metadata[x]['world']][bags_metadata[x]['brain_path']] = world_completed[bags_metadata[x]['world']][bags_metadata[x]['brain_path']] + 1
        elif bags_metadata[x]['world'] in world_completed:
            print('--- ENTRA 2 ---')
            world_completed[bags_metadata[x]['world']][bags_metadata[x]['brain_path']] = 1
        else:
            print('--- ENTRA 3 ---')
            world_completed[bags_metadata[x]['world']] = {} 
            world_completed[bags_metadata[x]['world']][bags_metadata[x]['brain_path']] = 1
            # world_completed[bags_metadata[x]['world']][bags_metadata[x]['brain_path']] = 1
    print('ORIENTATION MAE -> ' + str(lap_statistics['orientation_mae']))
    print('ORIENTATION TOTAL ERROR -> ' + str(lap_statistics['orientation_total_err']))
    
    if 'lap_seconds' in lap_statistics:
        print('LAP SECONDS -> ' + str(lap_statistics['lap_seconds']))
        print('CIRCUIT DIAMETER -> ' + str(lap_statistics['circuit_diameter']))
        print('AVERAGE SPEED -> ' + str(lap_statistics['average_speed']))

    for point in checkpoints:
        point_yml = yaml.load(str(point), Loader=yaml.FullLoader)
        # print(point)
        x_points.append(point_yml['pose']['pose']['position']['x'])
        y_points.append(point_yml['pose']['pose']['position']['y'])


    plt.scatter(x_points, y_points)
    plt.show()
    print('-------------------------------------------')
    
print(world_completed) 
print(experiments_statistics)
# Out:
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_classification_7w5v.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-100323.
# COMPLETED DISTANCE -> 516.8717387321204
# PERCENTAGE COMPLETED -> 120.05313016556627
# --- ENTRA 3 ---
# ORIENTATION MAE -> 65.38757606089915
# ORIENTATION TOTAL ERROR -> 212378.84704580042
# LAP SECONDS -> 150
# CIRCUIT DIAMETER -> 429.943014696523
# AVERAGE SPEED -> 2.8662867646434864
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_classification_7w5v.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-100642.
# COMPLETED DISTANCE -> 196.39423183222843
# PERCENTAGE COMPLETED -> 45.616234185596625
# ORIENTATION MAE -> 39.99976748506994
# ORIENTATION TOTAL ERROR -> 93679.4554500338
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_lstm_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-100909.
# COMPLETED DISTANCE -> 225.60390896267276
# PERCENTAGE COMPLETED -> 52.40072810905492
# ORIENTATION MAE -> 15.717741150479513
# ORIENTATION TOTAL ERROR -> 34374.6998960987
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_lstm_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-101149.
# COMPLETED DISTANCE -> 97.165062657726
# PERCENTAGE COMPLETED -> 22.568403417465614
# ORIENTATION MAE -> 29.374609256128352
# ORIENTATION TOTAL ERROR -> 22794.6967827556
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_lstm.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-101241.
# COMPLETED DISTANCE -> 268.9802991129994
# PERCENTAGE COMPLETED -> 62.47570614055537
# ORIENTATION MAE -> 16.66587481402224
# ORIENTATION TOTAL ERROR -> 35098.33235833084
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_lstm.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-101446.
# COMPLETED DISTANCE -> 4.062232376781269
# PERCENTAGE COMPLETED -> 0.9435294595304844
# ORIENTATION MAE -> 1.000067371823927
# ORIENTATION TOTAL ERROR -> 396.02667924227507
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-101517.
# COMPLETED DISTANCE -> 600.3458547546044
# PERCENTAGE COMPLETED -> 139.44155511773144
# --- ENTRA 2 ---
# ORIENTATION MAE -> 82.28874454835127
# ORIENTATION TOTAL ERROR -> 279370.2877416526
# LAP SECONDS -> 132
# CIRCUIT DIAMETER -> 432.8429591921217
# AVERAGE SPEED -> 3.2791133272130435
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-101831.
# COMPLETED DISTANCE -> 607.0475507950073
# PERCENTAGE COMPLETED -> 140.9981493881826
# --- ENTRA 1 ---
# ORIENTATION MAE -> 74.14291340325123
# ORIENTATION TOTAL ERROR -> 258758.7677773468
# LAP SECONDS -> 130
# CIRCUIT DIAMETER -> 432.22261079237035
# AVERAGE SPEED -> 3.324789313787464
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-102147.
# COMPLETED DISTANCE -> 2.3407793764746674
# PERCENTAGE COMPLETED -> 0.5436897979025115
# ORIENTATION MAE -> 0.9882643884111564
# ORIENTATION TOTAL ERROR -> 359.7282373816609
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-102227.
# COMPLETED DISTANCE -> 184.77498778753497
# PERCENTAGE COMPLETED -> 42.91744740119088
# ORIENTATION MAE -> 0.4654109301981651
# ORIENTATION TOTAL ERROR -> 592.002703212066
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_opencv.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-102353.
# COMPLETED DISTANCE -> 13.04731323605411
# PERCENTAGE COMPLETED -> 3.0304825682309633
# ORIENTATION MAE -> 0.6373556877361464
# ORIENTATION TOTAL ERROR -> 1428.314096216704
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_opencv.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-102607.
# COMPLETED DISTANCE -> 1.3003739956609965
# PERCENTAGE COMPLETED -> 0.30203618589778697
# ORIENTATION MAE -> 1.03627890509494
# ORIENTATION TOTAL ERROR -> 198.96554977822848
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_classification_7w5v.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-102628.
# COMPLETED DISTANCE -> 1.1797470327106434
# PERCENTAGE COMPLETED -> 0.14862496603712633
# ORIENTATION MAE -> 0.5744599798342429
# ORIENTATION TOTAL ERROR -> 219.4437122966808
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_classification_7w5v.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-102701.
# COMPLETED DISTANCE -> 663.7370560518398
# PERCENTAGE COMPLETED -> 83.61783897572411
# ORIENTATION MAE -> 0.7843360734273841
# ORIENTATION TOTAL ERROR -> 3420.489616216822
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_lstm_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-103226.
# COMPLETED DISTANCE -> 497.76472565969885
# PERCENTAGE COMPLETED -> 62.70858361531255
# ORIENTATION MAE -> 0.3669861763533854
# ORIENTATION TOTAL ERROR -> 2043.0120437592964
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_lstm_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-103747.
# COMPLETED DISTANCE -> 601.9864306508365
# PERCENTAGE COMPLETED -> 75.83847242634756
# ORIENTATION MAE -> 0.3384435577475187
# ORIENTATION TOTAL ERROR -> 1837.7485185690266
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_lstm.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-104309.
# COMPLETED DISTANCE -> 806.2446100876382
# PERCENTAGE COMPLETED -> 101.57099316161758
# --- ENTRA 3 ---
# ORIENTATION MAE -> 0.27352167495243457
# ORIENTATION TOTAL ERROR -> 1437.0828802000913
# LAP SECONDS -> 299
# CIRCUIT DIAMETER -> 795.9480120920114
# AVERAGE SPEED -> 2.662033485257563
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_lstm.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-104830.
# COMPLETED DISTANCE -> 1.105301974252552
# PERCENTAGE COMPLETED -> 0.13924635013203385
# ORIENTATION MAE -> 0.5800022319333802
# ORIENTATION TOTAL ERROR -> 225.62086822208488
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-104904.
# COMPLETED DISTANCE -> 0.6536539317276082
# PERCENTAGE COMPLETED -> 0.08234756325670511
# ORIENTATION MAE -> 0.8948246966703046
# ORIENTATION TOTAL ERROR -> 161.06844540065484
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-104927.
# COMPLETED DISTANCE -> 4.985827241700265
# PERCENTAGE COMPLETED -> 0.6281163536915889
# ORIENTATION MAE -> 0.8529069341553467
# ORIENTATION TOTAL ERROR -> 261.8424287856914
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-105005.
# COMPLETED DISTANCE -> 1.061345087533416
# PERCENTAGE COMPLETED -> 0.13370864534059337
# ORIENTATION MAE -> 0.8034145085534719
# ORIENTATION TOTAL ERROR -> 151.8453421166062
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-105033.
# COMPLETED DISTANCE -> 1.0024389282870096
# PERCENTAGE COMPLETED -> 0.12628762568584675
# ORIENTATION MAE -> 0.7848899689228945
# ORIENTATION TOTAL ERROR -> 264.5079195270155
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_opencv.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-105110.
# 20: Lap seems completed but lap point wasn't found
# COMPLETED DISTANCE -> 2737.7628607270062
# PERCENTAGE COMPLETED -> 344.9043743372207
# --- ENTRA 2 ---
# ORIENTATION MAE -> 0.5868771648373861
# ORIENTATION TOTAL ERROR -> 3410.34320487005
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_opencv.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-105633.
# COMPLETED DISTANCE -> 0.4513285956352411
# PERCENTAGE COMPLETED -> 0.056858542838415446
# ORIENTATION MAE -> 0.7076781189900153
# ORIENTATION TOTAL ERROR -> 140.82794567901306
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-121245.
# 20: Lap seems completed but lap point wasn't found
# COMPLETED DISTANCE -> 594.4623181246841
# PERCENTAGE COMPLETED -> 138.07499367523832
# --- ENTRA 1 ---
# ORIENTATION MAE -> 2.158848695169953
# ORIENTATION TOTAL ERROR -> 7197.601549696624
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-121601.
# COMPLETED DISTANCE -> 613.4149202423465
# PERCENTAGE COMPLETED -> 142.47709005332476
# --- ENTRA 1 ---
# ORIENTATION MAE -> 69.58495150423414
# ORIENTATION TOTAL ERROR -> 235197.1360843114
# LAP SECONDS -> 129
# CIRCUIT DIAMETER -> 432.1432855560468
# AVERAGE SPEED -> 3.3499479500468743
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-121919.
# COMPLETED DISTANCE -> 5.824914361681172
# PERCENTAGE COMPLETED -> 1.3529453240789635
# ORIENTATION MAE -> 1.0537207544828004
# ORIENTATION TOTAL ERROR -> 398.30644519449856
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-121955.
# COMPLETED DISTANCE -> 4.686302904348122
# PERCENTAGE COMPLETED -> 1.0884815137137114
# ORIENTATION MAE -> 0.6106232014291044
# ORIENTATION TOTAL ERROR -> 351.10834082173506
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-122036.
# COMPLETED DISTANCE -> 1547.2264968538234
# PERCENTAGE COMPLETED -> 194.92016438327664
# --- ENTRA 2 ---
# ORIENTATION MAE -> 87.35626628508345
# ORIENTATION TOTAL ERROR -> 485089.34668106836
# LAP SECONDS -> 150
# CIRCUIT DIAMETER -> 798.3593694619611
# AVERAGE SPEED -> 5.322395796413074
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression_merged.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-122559.
# COMPLETED DISTANCE -> 0.8294480054225183
# PERCENTAGE COMPLETED -> 0.10449416545870646
# ORIENTATION MAE -> 0.7698714334444607
# ORIENTATION TOTAL ERROR -> 127.79865795178048
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-122629.
# COMPLETED DISTANCE -> 1.7547828312252396
# PERCENTAGE COMPLETED -> 0.22106818789291344
# ORIENTATION MAE -> 0.8157929309526007
# ORIENTATION TOTAL ERROR -> 271.65904600721603
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-122708.
# COMPLETED DISTANCE -> 844.7843950548458
# PERCENTAGE COMPLETED -> 106.4262494775996
# --- ENTRA 2 ---
# ORIENTATION MAE -> 0.27559461328396956
# ORIENTATION TOTAL ERROR -> 1470.0216672566935
# LAP SECONDS -> 284
# CIRCUIT DIAMETER -> 794.5198050718177
# AVERAGE SPEED -> 2.797604947435978
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-134355.
# COMPLETED DISTANCE -> 2.5755578904307455
# PERCENTAGE COMPLETED -> 0.5982214996457464
# ORIENTATION MAE -> 1.1307625373245402
# ORIENTATION TOTAL ERROR -> 439.86662701924615
# -------------------------------------------
# -------------------------------------------
# WORLD -> simple_circuit.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-simple-circuit.
# CIRCUIT DIAMETER -> 430.53582861129763
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-134429.
# COMPLETED DISTANCE -> 1.3182339941787358
# PERCENTAGE COMPLETED -> 0.30618450465103614
# ORIENTATION MAE -> 0.362878813091076
# ORIENTATION TOTAL ERROR -> 136.0795549091535
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-134503.
# COMPLETED DISTANCE -> 0.7200120775659499
# PERCENTAGE COMPLETED -> 0.09070738692911538
# ORIENTATION MAE -> 0.5885318835719987
# ORIENTATION TOTAL ERROR -> 104.75867527581578
# -------------------------------------------
# -------------------------------------------
# WORLD -> many_curves.launch
# BRAIN PATH -> brain_f1_keras_regression.py
# ROBOT TYPE -> f1
# [INFO]  Successfully created the data folder lap-many-curves.
# CIRCUIT DIAMETER -> 793.7744674847859
# [INFO]  Successfully created the data folder first_experiment_bags/20201229-134528.
# COMPLETED DISTANCE -> 885.9643998728881
# PERCENTAGE COMPLETED -> 111.61412166357809
# --- ENTRA 1 ---
# ORIENTATION MAE -> 73.15874514185207
# ORIENTATION TOTAL ERROR -> 411152.1476972086
# LAP SECONDS -> 271
# CIRCUIT DIAMETER -> 793.5580471255269
# AVERAGE SPEED -> 2.928258476477959
# -------------------------------------------
# {'simple_circuit.launch': {'brain_f1_keras_classification_7w5v.py': 1, 'brain_f1_keras_regression_merged.py': 4}, 'many_curves.launch': {'brain_f1_keras_lstm.py': 1, 'brain_f1_opencv.py': 1, 'brain_f1_keras_regression_merged.py': 1, 'brain_f1_keras_regression.py': 2}}
# [{'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_classification_7w5v.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 516.8717387321204, 'percentage_completed': 120.05313016556627, 'orientation_mae': 65.38757606089915, 'orientation_total_err': 212378.84704580042, 'lap_seconds': 150, 'circuit_diameter': 429.943014696523, 'average_speed': 2.8662867646434864}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_classification_7w5v.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 196.39423183222843, 'percentage_completed': 45.616234185596625, 'orientation_mae': 39.99976748506994, 'orientation_total_err': 93679.4554500338}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_lstm_merged.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 225.60390896267276, 'percentage_completed': 52.40072810905492, 'orientation_mae': 15.717741150479513, 'orientation_total_err': 34374.6998960987}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_lstm_merged.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 97.165062657726, 'percentage_completed': 22.568403417465614, 'orientation_mae': 29.374609256128352, 'orientation_total_err': 22794.6967827556}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_lstm.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 268.9802991129994, 'percentage_completed': 62.47570614055537, 'orientation_mae': 16.66587481402224, 'orientation_total_err': 35098.33235833084}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_lstm.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 4.062232376781269, 'percentage_completed': 0.9435294595304844, 'orientation_mae': 1.000067371823927, 'orientation_total_err': 396.02667924227507}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_regression_merged.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 600.3458547546044, 'percentage_completed': 139.44155511773144, 'orientation_mae': 82.28874454835127, 'orientation_total_err': 279370.2877416526, 'lap_seconds': 132, 'circuit_diameter': 432.8429591921217, 'average_speed': 3.2791133272130435}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_regression_merged.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 607.0475507950073, 'percentage_completed': 140.9981493881826, 'orientation_mae': 74.14291340325123, 'orientation_total_err': 258758.7677773468, 'lap_seconds': 130, 'circuit_diameter': 432.22261079237035, 'average_speed': 3.324789313787464}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_regression.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 2.3407793764746674, 'percentage_completed': 0.5436897979025115, 'orientation_mae': 0.9882643884111564, 'orientation_total_err': 359.7282373816609}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_keras_regression.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 184.77498778753497, 'percentage_completed': 42.91744740119088, 'orientation_mae': 0.4654109301981651, 'orientation_total_err': 592.002703212066}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_opencv.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 13.04731323605411, 'percentage_completed': 3.0304825682309633, 'orientation_mae': 0.6373556877361464, 'orientation_total_err': 1428.314096216704}}, {'world': 'simple_circuit.launch', 'brain_path': 'brain_f1_opencv.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 1.3003739956609965, 'percentage_completed': 0.30203618589778697, 'orientation_mae': 1.03627890509494, 'orientation_total_err': 198.96554977822848}}, {'world': 'many_curves.launch', 'brain_path': 'brain_f1_keras_classification_7w5v.py', 'robot_type': 'f1', 'lap_statistics': {'completed_distance': 1.1797470327106434, 'percentage_completed': 0.14862496603712633, 'orientation_mae': 0.57445 ...

# %%
import matplotlib.patches as mpatches

completed_laps = 0
experiment_names = []
experiments_completed_distances = []
experiments_percentage_completed = []
experiments_orientation_mae = []
experiments_orientation_total_err = []
experiments_lap_seconds = []
experiments_circuit_diameter = []
experiments_average_speed = []
circuit_bar_colors = []
for experimment_counter, experiment in enumerate(experiments_statistics):
    experiment_names.append(str(experimment_counter) + '. ' + experiment['brain_path'])
    experiments_completed_distances.append(experiment['lap_statistics']['completed_distance'])
    experiments_percentage_completed.append(experiment['lap_statistics']['percentage_completed'])
    experiments_orientation_mae.append(experiment['lap_statistics']['orientation_mae'])
    experiments_orientation_total_err.append(experiment['lap_statistics']['orientation_total_err'])
    if experiment['lap_statistics']['percentage_completed'] > 100:
        completed_laps += 1
        
    if 'lap_seconds' in experiment['lap_statistics']:
        experiments_lap_seconds.append(experiment['lap_statistics']['lap_seconds'])
        experiments_circuit_diameter.append(experiment['lap_statistics']['circuit_diameter'])
        experiments_average_speed.append(experiment['lap_statistics']['average_speed'])
    else:
        experiments_lap_seconds.append(0)
        experiments_circuit_diameter.append(0)
        experiments_average_speed.append(0)
        
    if experiment['world'] == 'simple_circuit.launch':
        circuit_bar_colors.append('black')
    else:
        circuit_bar_colors.append('red')

world_completed_circuit_colors = []
world_completed_brains = []
world_completed_brain_number = []
for key, value in world_completed.items():
    if key == 'simple_circuit.launch':
        world_completed_circuit_colors.append('black')
    else:
        world_completed_circuit_colors.append('red')

    for key_2, value_2 in value.items():
        world_completed_brains.append(key_2)
        world_completed_brain_number.append(value_2)
    

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_completed_distances, color=circuit_bar_colors)
plt.suptitle('Completed distance for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('Completed distance', fontsize=60)
plt.xticks(rotation=90)
black_patch = mpatches.Patch(color='black', label='simple_circuit')
red_patch = mpatches.Patch(color='red', label='many_curves')
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()


plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_percentage_completed, color=circuit_bar_colors)
plt.suptitle('Completed percentage for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('Completed percentage', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_orientation_mae, color=circuit_bar_colors)
plt.suptitle('Orientation mae for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('Orientation mae', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_orientation_total_err, color=circuit_bar_colors)
plt.suptitle('Orientation total error for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('Orientation total error', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_lap_seconds, color=circuit_bar_colors)
plt.suptitle('Lap seconds for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('seconds', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_circuit_diameter, color=circuit_bar_colors)
plt.suptitle('Circuit diameter for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('meters', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(experiment_names, experiments_average_speed, color=circuit_bar_colors)
plt.suptitle('Average speed for each brain', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('speed', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

plt.figure(figsize=(120, 20))
plt.rc('xtick',labelsize=40)
plt.rc('ytick',labelsize=50)
plt.bar(world_completed_brains, world_completed_brain_number, color=world_completed_circuit_colors)
plt.suptitle('Completed laps for each circuit', fontsize=100)
plt.xlabel('Brain', fontsize=60)
plt.ylabel('Completed laps', fontsize=60)
plt.xticks(rotation=90)
plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 60})
plt.show()

# %%
# Stats for each brain on each circuit

import matplotlib.patches as mpatches


circuit_bar_colors = []


experiments_completed_distances_brains = {}
experiments_percentage_completed_brains = {}
experiments_orientation_mae_brains = {}
experiments_orientation_total_err_brains = {}
experiments_lap_seconds_brains = {}
experiments_circuit_diameter_brains = {}
experiments_average_speed_brains = {}



for experimment_counter, experiment in enumerate(experiments_statistics):
    if experiment['brain_path'] in experiments_completed_distances_brains:
        if experiment['world'] in experiments_completed_distances_brains[experiment['brain_path']]:
            experiments_completed_distances_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['completed_distance'])
            experiments_percentage_completed_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['percentage_completed'])
            experiments_orientation_mae_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['orientation_mae'])
            experiments_orientation_total_err_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['orientation_total_err'])
        
            if 'lap_seconds' in experiment['lap_statistics']:
                experiments_lap_seconds_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['lap_seconds'])
                experiments_circuit_diameter_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['circuit_diameter'])
                experiments_average_speed_brains[experiment['brain_path']][experiment['world']].append(experiment['lap_statistics']['average_speed'])
            else:   
                experiments_lap_seconds_brains[experiment['brain_path']][experiment['world']].append(0)
                experiments_circuit_diameter_brains[experiment['brain_path']][experiment['world']].append(0)
                experiments_average_speed_brains[experiment['brain_path']][experiment['world']].append(0)
        else:
            experiments_completed_distances_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['completed_distance']]
            experiments_percentage_completed_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['percentage_completed']]
            experiments_orientation_mae_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['orientation_mae']]
            experiments_orientation_total_err_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['orientation_total_err']]
    
            if 'lap_seconds' in experiment['lap_statistics']:
                experiments_lap_seconds_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['lap_seconds']]
                experiments_circuit_diameter_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['circuit_diameter']]
                experiments_average_speed_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['average_speed']]
            else:   
                experiments_lap_seconds_brains[experiment['brain_path']][experiment['world']] = [0]
                experiments_circuit_diameter_brains[experiment['brain_path']][experiment['world']] = [0]
                experiments_average_speed_brains[experiment['brain_path']][experiment['world']] = [0]
    
    else:
        experiments_completed_distances_brains[experiment['brain_path']] = {}
        experiments_percentage_completed_brains[experiment['brain_path']] = {}
        experiments_orientation_mae_brains[experiment['brain_path']] = {}
        experiments_orientation_total_err_brains[experiment['brain_path']] = {}
        experiments_completed_distances_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['completed_distance']]
        experiments_percentage_completed_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['percentage_completed']]
        experiments_orientation_mae_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['orientation_mae']]
        experiments_orientation_total_err_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['orientation_total_err']]

        if 'lap_seconds' in experiment['lap_statistics']:
            experiments_lap_seconds_brains[experiment['brain_path']] = {}
            experiments_circuit_diameter_brains[experiment['brain_path']] = {}
            experiments_average_speed_brains[experiment['brain_path']] = {}
            
            experiments_lap_seconds_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['lap_seconds']]
            experiments_circuit_diameter_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['circuit_diameter']]
            experiments_average_speed_brains[experiment['brain_path']][experiment['world']] = [experiment['lap_statistics']['average_speed']]

        else:
            experiments_lap_seconds_brains[experiment['brain_path']] = {}
            experiments_circuit_diameter_brains[experiment['brain_path']] = {}
            experiments_average_speed_brains[experiment['brain_path']] = {}
            
            experiments_lap_seconds_brains[experiment['brain_path']][experiment['world']] = [0]
            experiments_circuit_diameter_brains[experiment['brain_path']][experiment['world']] = [0]
            experiments_average_speed_brains[experiment['brain_path']][experiment['world']] = [0]
            


black_patch = mpatches.Patch(color='black', label='simple_circuit')
red_patch = mpatches.Patch(color='red', label='many_curves')

# Completed distances for each brain 
for brain_experiments in experiments_completed_distances_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_completed_distances_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_completed_distances_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Total distance ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Total distance', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()
    
    
# Completed percentage for each brain 
for brain_experiments in experiments_percentage_completed_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_percentage_completed_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_percentage_completed_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Percentage completed ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Total percentage', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()
    
    
# Orientation mae for each brain 
for brain_experiments in experiments_orientation_mae_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_orientation_mae_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_orientation_mae_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Orientation mae ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Orientation mae', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()
    
# MAE total error for each brain 
for brain_experiments in experiments_orientation_total_err_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_orientation_total_err_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_orientation_total_err_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Total mae error ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Error', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()
    

# Lap seconds for each brain 
for brain_experiments in experiments_lap_seconds_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_lap_seconds_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_lap_seconds_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Lap seconds for ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Error', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()
    
# Circuit diameter for each brain 
for brain_experiments in experiments_circuit_diameter_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_circuit_diameter_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_circuit_diameter_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Circuit diameter for ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Error', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()

# Average speed for each brain 
for brain_experiments in experiments_average_speed_brains:
    brain_circuit_experiments = []
    circuit_bar_colors = []
    for brain_circuit_experiment in experiments_average_speed_brains[brain_experiments]:
        brain_circuit_experiments = brain_circuit_experiments + experiments_average_speed_brains[brain_experiments][brain_circuit_experiment]
        if brain_circuit_experiment == 'simple_circuit.launch':
            circuit_bar_colors.append('black')
        else:
            circuit_bar_colors.append('red')
        
        
    names = []
    for x in range(0, len(brain_circuit_experiments)):
        names.append(str(x))
    plt.bar(names, brain_circuit_experiments, color=circuit_bar_colors)
    plt.suptitle('Average speed for ' + brain_experiments, fontsize=20)
    plt.xlabel('Brain', fontsize=20)
    plt.ylabel('Error', fontsize=20)
    plt.legend(handles=[black_patch, red_patch], loc=2, prop={'size': 10})
    plt.show()

# %%
# Sacar estadísticas medias por cada cerebro en cada circuito
# Barras de medias de cada estadística por cerebro y circuito.
